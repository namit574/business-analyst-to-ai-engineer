# %%
students = [
    {"name": "Alice", "score": 85},
    {"name": "Bob", "score": 72},
    {"name": "Charlie", "score": 90},
    {"name": "David", "score": 60},
    {"name": "Eva", "score": 95}
]

# %%
for i in students:
    x=i.get("name")
    y=i.get("score")
    if y >=80:
        print(x)
# Out:
# Alice
# Charlie
# Eva

# %%
import numpy as np
scoree = []
for i in students:
    scoree.append(i['score'])

# %%
avg = sum(scoree)/len(scoree)
avg
# Out:
# 80.4

# %%
lst = []
for i in students:
    lst.append(i['score'])

# %%
print(max(lst))
# Out:
# 95
