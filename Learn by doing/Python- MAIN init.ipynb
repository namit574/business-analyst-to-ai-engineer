# %% [markdown]
# # What is __main__ in Python?
#
# In Python, __main__ is used to check whether a file is being run directly or imported as a module.

# %% [markdown]
# the special variable __name__
#
# ython automatically sets this variable.
#
# If the file is run directly, __name__ becomes "__main__".
#
# If the file is imported, __name__ becomes the module name.
#
#
# which means that for example if we write some code inside the file all the functions are inside that file and in end we write
#
# if __name__ = '__main__
#     do this
#
# then this will act as entry point of the code , rest code will also run as is
#
# but if we import user defined functions from a different file and then we do
#
#
# then this value of this __nme__ will be that files name from where we defined that function

# %%
def area_of_rectangle(length , width):
    print('value of __name__ is',__name__)
    area = length*width
    return area

# %%
area_of_rectangle(34,12) #see here the value of __name__ is main
# Out:
# value of __name__ is __main__
# 408

# %%
from TimePassCodes import area_of_triangle #this is throwing error as TimePassCodes is pynb fiile it should be py file
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from TimePassCodes import area_of_triangle
#
# ModuleNotFoundError: No module named 'TimePassCodes'

# %%
from file_with_function import area_of_rectangle # see it got imported

# %%
area_of_rectangle(12,12)
print("value of __name__",__name__)
# Out:
# value of __name__ is file_with_function
# value of __name__ __main__

# %% [markdown]
# in above example we printed value of __name__ which gave us the file name where the function
# area_of_ractangle imported from
# and in that file function has that print statment which gave us value of__name__ which is __main__

# %% [markdown]
# # when should we use if __name__ = '__main__'
#
# 1) when we want all the fucntions should be in that file only
# 2) we can write a main() function and in the end we can write
#
# if __name__ = '__main__':
#     main()
#
# then only it will run
