# %%
can = 'soda'

# %%
can
# Out:
# 'soda'

# %%
type(can)
# Out:
# str

# %%
a=5
b=7

# %%
a+b
# Out:
# 12

# %%
a*b #multiply
a**b#a power b
a-b#a - b
a%b#remainder
a//b#devide
# Out:
# 0

# %%
abc = '120' #this is a string
type(abc)
# Out:
# str

# %%
int(abc) # to convert a variable into string the string should be in numric characters also we need to store it into a variable
type(abc)
# Out:
# str

# %%
fafa = int(abc)
type(fafa)
# Out:
# int

# %%
first = "rahul"
last = "sharma"

# %%
print(first+" "+last)
# Out:
# rahul sharma

# %%
print(first+last)
# Out:
# rahulsharma

# %%
statement = f"Boys first name is {first} and last name is {last}" #using f string notation

# %%
statement
# Out:
# 'Boys first name is rahul and last name is sharma'

# %%
full = first+" "+last
full
# Out:
# 'rahul sharma'

# %%
full[0]
# Out:
# 'r'

# %%
full[1]
# Out:
# 'a'

# %%
full[0:5]
# Out:
# 'rahul'

# %%
full[6:9]
# Out:
# 'sha'

# %%
para = "this is a long string and we have to use 3 quotes to store it using a different method using new line"

# %%
new_para = '''this is a long string and we have
to use 3 quotes to store
it using a different method using new line'''

# %%
new_para
# Out:
# 'this is a long string and we have\nto use 3 quotes to store\nit using a different method using new line'

# %%
#now to find something in a string we use find

# %%
to_find = "long"

# %%
to_find in (new_para) # true means long is present in string new_para
# Out:
# True

# %%
new_para.find(to_find) #10 means its on 10th place stating from 0
# Out:
# 10

# %%
new_para.index("long") # another way to find index of long in string
# Out:
# 10

# %%
dir(new_para) # functions available to operate on srtings
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
some_text =  "jaipur|udaipur|jaiselmer|jodhpur"

# %%
some_text # is this kind of string is given then we can use split to split the string
# Out:
# 'jaipur|udaipur|jaiselmer|jodhpur'

# %%
some_text_2 = some_text.split("|")

# %%
some_text_2
# Out:
# ['jaipur', 'udaipur', 'jaiselmer', 'jodhpur']

# %%
for i in some_text_2:
    print(i)
# Out:
# jaipur
# udaipur
# jaiselmer
# jodhpur

# %%
some_data = "   this is   a  text with  extra spaces    " #string with extra spaces called whitespaces

# %%
some_data.strip() #this cleared extra spaces from start and end
# Out:
# 'this is   a  text with  extra spaces'

# %%
some_data
# Out:
# '   this is   a  text with  extra spaces    '

# %%
some_data = " ".join(some_data.strip())

# %%
some_data
# Out:
# 't h i s   i s       a     t e x t   w i t h     e x t r a   s p a c e s'

# %%
new_some_data = " ".join(some_data.strip())

# %%
new_some_data
# Out:
# 't   h   i   s       i   s               a           t   e   x   t       w   i   t   h           e   x   t   r   a       s   p   a   c   e   s'

# %%
new_some_data  = new_some_data.replace(" ","") # as we see above this string text is completely ruined with spaces so we removed all

# %%
new_some_data #string after removing all spaces using .replace()
# Out:
# 'thisisatextwithextraspaces'

# %%
pip install wordninja
# Out:
# ...
#      -------------------------------------- 541.6/541.6 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for wordninja: filename=wordninja-2.0.0-py3-none-any.whl size=541535 sha256=5451fd28e1a746271e6c6aaef337a2ebd9f0980fbdc1af2a7075bc558d70c3a8
#   Stored in directory: c:\users\namitjai\appdata\local\pip\cache\wheels\7c\e6\e6\e95742bec8d8c3d40687c0c50b8537bb71347ce84a2b322234
# Successfully built wordninja
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import wordninja

# %%
new_text = wordninja.split(new_some_data) # using wordninja nlp we split into list of words

# %%
new_text
# Out:
# ['this', 'is', 'a', 'text', 'with', 'extra', 'spaces']

# %%
new_text = " ".join(new_text) #converting a list into a string

# %%
new_text
# Out:
# 'this is a text with extra spaces'

# %%
some_data
# Out:
# '   this is   a  text with  extra spaces    '

# %%
some_data = wordninja.split(some_data)

# %%
some_data
# Out:
# ['this', 'is', 'a', 'text', 'with', 'extra', 'spaces']

# %%
some_data = " ".join(some_data)

# %%
some_data
# Out:
# 'this is a text with extra spaces'

# %%
type(some_data)
# Out:
# str

# %%
xyz = ["2","3","5"]

# %%
new_xyz = " ".join(xyz) # using this we can convert a list into a string

# %%
new_xyz
# Out:
# '2 3 5'

# %%
type(new_xyz)
# Out:
# str

# %%
file_name = "readme.pdf" # fine the file extension

# %%
ext = file_name.split(".")[1]

# %%
ext
# Out:
# 'pdf'

# %%
text = wordninja.split(some_text)

# %%
text
# Out:
# ['jaipur', 'udaipur', 'j', 'a', 'is', 'elmer', 'jodhpur']

# %%
new_textt = " ".join(text)

# %%
new_textt.replace(" ","")
# Out:
# 'jaipurudaipurjaiselmerjodhpur'

# %%
new_textt = wordninja.split(new_textt)

# %%
new_textt
# Out:
# ['jaipur', 'udaipur', 'j', 'a', 'is', 'elmer', 'jodhpur']

# %%
#Exercise below

# %% [markdown]
# 1) Open the Jupyter notebook and type this code help(str) in the code cell and press CTRL+enter. Now see what it returns? Go through these string methods and try to practice them.
#
# 2) Create two variables to store how many fruits and vegetables you eat in a day. Now Print "I eat x vegetables and y fruits daily" where x and y present vegetables and fruits that you eat every day. Use python f string for this.
#
# 3) Create a variable and store the string “The Himalayas are one of the youngest mountain ranges on the planet.”
#
# Print ‘The Himalayas’ using slice operator
# Print “mountain range” using a negative index
# Print “The Himalayas on the planet” using slice as well as f-string
#
# 4) You have created a string variable called string= ”There are 9 planets in the solar system”. After some time, you have realized that your sentence is incorrect and there are only 8 planets, now correct your sentence by replacing the incorrect words. (Bonus: Try to do it in one line)

# %%
#1)

help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
demo_string = "this is a demo string"

# %%
to_find = "demo"

# %%
demo_string.find(to_find) # this gives at what place to_find is present in demo_string now we will find if yes or no
# Out:
# 10

# %%
to_find in demo_string # is present or not
# Out:
# True

# %% [markdown]
# 2) Create two variables to store how many fruits and vegetables you eat in a day. Now Print "I eat x vegetables and y fruits daily" where x and y present vegetables and fruits that you eat every day. Use python f string for this.

# %%
fruits = 4
vegitable = 7

print(f" i eat {fruits} fruits and {vegitable} vegitables per day")
# Out:
#  i eat 4 fruits and 7 vegitables per day

# %% [markdown]
# 3) Create a variable and store the string “The Himalayas are one of the youngest mountain ranges on the planet.”
#
# Print ‘The Himalayas’ using slice operator
# Print “mountain range” using a negative index
# Print “The Himalayas on the planet” using slice as well as f-string

# %%
var1 = "The Himalayas are one of the youngest mountain ranges on the planet"

# %%
var1[0:13]
# Out:
# 'The Himalayas'

# %%
var1[-29:-15]
# Out:
# 'mountain range'

# %%
first = var1[0:13]
second = var1[-13:]

# %%
first + " "+ second
# Out:
# 'The Himalayas on the planet'

# %%
print(f"{first} {second}")
# Out:
# The Himalayas on the planet

# %% [markdown]
# 4) You have created a string variable called string= ”There are 9 planets in the solar system”. After some time, you have realized that your sentence is incorrect and there are only 8 planets, now correct your sentence by replacing the incorrect words. (Bonus: Try to do it in one line)

# %%
var2 = "There are 9 planets in the solar system"

# %%
var2 = var2.replace("9","8")

# %%
var2
# Out:
# 'There are 8 planets in the solar system'

# %%
string = "discord is"
print(len(string))
# Out:
# 10

# %%
word = 'python'
"pyT" in word
# Out:
# False

# %%
s = "12345a"
print(s.isdigit())
# Out:
# False

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 help(isdigit())
#
# NameError: name 'isdigit' is not defined

# %%
my_string = "Hello world Python"
words = my_string.split()[2]

# %%
words
# Out:
# 'Python'

# %%
filename = "python.pdf.csv"

# %%
extention = filename.split(".")[2]

# %%
extention
# Out:
# 'csv'
