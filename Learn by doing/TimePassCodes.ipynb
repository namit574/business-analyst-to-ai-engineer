# %%
#getting age
import datetime

current_year = datetime.datetime.now().year
current_year
# Out:
# 2026

# %%
def my_age():
    dob =int(input("Enter your year of birth:"))
    age = current_year-dob
    return age

# %%
my_age()
# Out:
# Enter your year of birth:1996
# 30

# %%
###CLASS

class CricketPlayer:
    def __init__(self,fname,lname,dob):
        self.first_name = fname
        self.last_name = lname
        self.dob = dob
        self.scores = []

        
        
    def add_score(self,score):
        self.scores.append(score)
        
   
        
        
virat = CricketPlayer('virat','kohli','1996')
virat.add_score(23)

# %%
print(virat)

# %%
import datetime
class Car:
    def __init__(self,brand,year):
        self.brand = brand
        self.year = year
        
    def drive():
        print("the car is driving")
    def age(car_bought_year): #local variable 
        return datetime.datetime.now().year - car_bought_year
    def __str__(self):
        return f"Brand: {self.brand} Year: {self.year}"

# %%
first_car = Car("skoda","2019")
second_car = Car("honda","2015")

# %%
print(first_car)
print(second_car)
# Out:
# Brand: skoda Year: 2019
# Brand: honda Year: 2015

# %%
Car.drive()
# Out:
# the car is driving

# %%
print(first_car_age)
# Out:
# 26

# %%
def car_age(bought):
    return datetime.datetime.now().year - bought

# %%
car_age(2015)
# Out:
# 11

# %%
class Cricket:
    def __init__(self,player_name,team):
        self.player_name = player_name
        self.team = team #we have defined a class here 
    
    def coach(self):
        return f"coach is vinod kamli"

# %%
P1 = Cricket("virat","india")

# %%
print(Cricket.coach(P1))
# Out:
# coach is vinod kamli

# %%
def area_of_rectangle(length , width):
    print('value of __name__ is',__name__)
    area = length*width
    return area

# %%
class Pet:
    def __init__(self, name, sound):
        self.name = name
        self.sound = sound

    def speak(self):
        print(self.sound)

# %%
my_pet = Pet('peter','woof')
my_pet.speak()
# Out:
# woof
